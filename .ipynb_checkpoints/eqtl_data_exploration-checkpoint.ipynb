# %% [raw]
# Look at all the eqtl data! (why is it so weird...)

# %%
import sys
sys.path.append('/home/kal/K27act_models/convolution_model/')
sys.path.append('/home/kal/K27act_models/cg_model/')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ucscgenome
import pyliftover

#load in the DNA
genome = ucscgenome.Genome('/home/kal/.ucscgenome/hg19.2bit')
genome38 = ucscgenome.Genome('/home/kal/.ucscgenome/hg38.2bit')

# %%
# import the ibd varients
ibd_l = pd.read_table('/home/kal/K27act_models/eqtl_data/IBD_credible_sets.csv')
ibd_l.chr = ['chr' + str(n) for n in ibd_nonfm['chr']]
ibd_c.to_csv('/home/kal/K27act_models/eqtl_data/IBD_credible_sets.csv', sep='\t', index=False)
print(len(ibd_c))
ibd_c.head()

# %%
# import the ibd varients
ibd_c = pd.read_table('/home/kal/K27act_models/eqtl_data/IBD_credible_sets.csv')
ibd_nonfm.chr = ['chr' + str(n) for n in ibd_nonfm['chr']]
ibd_c.to_csv('/home/kal/K27act_models/eqtl_data/IBD_credible_sets.csv', sep='\t', index=False)
print(len(ibd_c))
ibd_c.head()
# Out:
# 154
#    HD  chr  region (mb)  signal evidence.set tier2  region_start   \
# 0   1    1    2.36-2.84       1        H,L,M    No     2,356,887
# 1   2    1    7.69-8.26       1        H,L,M    No     7,688,180
# 2   4    1  20.10-20.30       1        H,L,M    No    20,098,249
# 3   4    1  20.10-20.30       2        H,L,M    No            NaN
# 4   4    1  20.10-20.30       3          H,M    No            NaN
#
#     region_end   region_len   credible_start   \
# 0    2,835,671      478,784        2,472,081
# 1    8,256,130      567,950        8,021,740
# 2   20,303,899      205,650       20,165,971
# 3           NaN          NaN      20,142,270
# 4           NaN          NaN      20,135,822
#
#                          ...                          AF_CD  AF_UC  INFO.best  \
# 0                        ...                          0.487  0.472        1.0
# 1                        ...                          0.150  0.147        1.0
# ...

# %%
# import the useless ibd varients
ibd_l = pd.read_table('/home/kal/K27act_models/eqtl_data/IBD_list_of_varients.csv')
for n in ibd_l['chr']:
    try:
        'chr' + str(int(n)) 
    except ValueError:
        print(n)
ibd_l.to_csv('/home/kal/K27act_models/eqtl_data/IBD_list_of_varients.csv', sep='\t', index=False)
print(len(ibd_l))
print(ibd_l.keys)
ibd_l.head()
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 4341
# <bound method NDFrame.keys of          HD   chr  region (mb)  signal  credible_nSNP tier2   trait trait.1  \
# 0       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 1       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 2       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 3       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 4       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 5       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 6       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 7       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# 8       1.0   1.0    2.36-2.84     1.0           71.0    No      UC      UC
# ...

# %%
[print(row) for index, row in ibd_l.iterrows() if row['chr'] == 'NaN']
# Out:
# []

# %%
# check if reference matches genome
count=0
for idx, row in ibd_nonfm.iterrows():
    if genome[row.chr][row.position].lower() != row.refAllele.lower()[0]:
        print('Should be {}'.format(genome[row.chr][row.position].lower()))
        print('Actually is {}'.format(row.refAllele.lower()))
        print('Alternate is {}'.format(row.altAllele.lower()))
        count+=1
        
print(count)

# %%
ibd_nonfm = pd.read_table('/home/kal/K27act_models/eqtl_data/nonFM.variants.annot.txt', header=None)
ibd_nonfm.columns='chr position name refAllele altAllele'.split()
ibd_nonfm.chr = ['chr' + str(n) for n in ibd_nonfm['chr']]
ibd_nonfm.position = ibd_nonfm.position - 1
ibd_nonfm.head()

# %%
ibd_fm = pd.read_table('/home/kal/K27act_models/eqtl_data/FM.variants.txt')

# get the data in the right format
ibd_fm.chr = ['chr' + str(n) for n in ibd_fm['chr']]
ibd_fm.position = ibd_fm.position - 1
ibd_fm = ibd_fm.rename(index=str, columns={'A0':'refAllele', 'A1': 'altAllele'})
ibd_fm.head()

# %%
# check if reference matches genome
count=0
for idx, row in ibd_fm.iterrows():
    if genome[row.chr][row.position].lower() != row.refAllele[0].lower():
        print('Should be {}'.format(genome[row.chr][row.position].lower()))
        print('Actually is {}'.format(row.refAllele.lower()))
        print('Alternate is {}'.format(row.altAllele.lower()))
        count+=1
        
print(count)

# %%
eqtl = pd.read_table('/home/kal/K27act_models/eqtl_data/Cells_EBV-transformed_lymphocytes.hg19.txt')
eqtl = eqtl.rename(index=str, columns={'eqtl.ref.allele':'refAllele', 'eqtl.alt.allele': 'altAllele'})
eqtl.position = eqtl.position - 1
eqtl['position38'] = [int(e.split('_')[1]) - 1 for e in eqtl['variant_id']]
eqtl['chr38'] = [e.split('_')[0] for e in eqtl['variant_id']]
eqtl.head()

# %%
print('{}% wrong referenes hg19'.format(sum([genome[row.chr][row.position].lower() != row.refAllele[0].lower() for idx, row in eqtl.iterrows()])/len(eqtl) *100))
print('{}% wrong referenes hg38'.format(sum([genome38[row.chr38][row.position38].lower() != row.refAllele[0].lower() for idx, row in eqtl.iterrows()])/len(eqtl) *100))

# %%
mini=eqtl.sample(8000)
print('{}% wrong referenes hg38'.format(sum([genome38[row.chr][row.position38].lower() != row.refAllele[0].lower() for idx, row in mini.iterrows()])/len(mini) *100))
print('{}% wrong referenes hg38'.format(sum([genome38[row.chr][row.position38].lower() != row.refAllele[0].lower() for idx, row in mini.iterrows()])/len(mini) *100))

# %%
# check if reference matches genome
count=0
for idx, row in eqtl.iterrows():
    try:
        if genome38[row.chr38][row.position].lower() != row.refAllele[0].lower():
            print('Should be {}, but is {}'.format(genome38[row.chr38][row.position38].lower(), row.refAllele.lower()))
            count+=1
    except ValueError:
        print(row)
print(count)

# %%
# replicate previous posterior prob plots from the promotor label
num_groups = 5
split_column='PosteriorProb'
test_columns=['Promoter', 'SpliceSite', 'Coding']
for test_column in test_columns:
    enrichment_data=list()
    names=dict()
    for i in range(num_groups):
        # get quintile values
        min_fold, max_fold = ibd.quantile([i/num_groups, (i+1)/num_groups])[split_column]
        names[i]='{:.2}-{:.2}'.format(min_fold, max_fold)
        subset=ibd[(ibd[split_column] > min_fold) & (ibd[split_column] <= max_fold)]
        enrichment_data.append(len(subset[subset[test_column]])/len(subset))

    plt.xticks(range(num_groups), names.values(), rotation=-45)
    plt.title('{} enrichment for {}'.format(split_column, test_column))
    plt.xlabel(test_column)
    plt.ylabel('Enrichment (num samples/total num)')
    plt.bar(range(num_groups), enrichment_data)
    plt.show()

# %%
def snv_gen(peaks, genome, alt=False):
    """Generate sequnces from snv data.
    
    Arguments:
        peaks -- from a bed file.
        genome -- to pull bed from.
    Keywords:
        alt -- give alternate allele version.
    Returns:
        seq -- sequence with the alternate or refernce allele, centered around the position. """
    for index, row in peaks.iterrows():
        if row.position > 128:
            seq = sequence.encode_to_onehot(genome[row.chr][row.position-128:row.position+128])
            if alt:
                seq[128] = sequence.encode_to_onehot(row.altAllele.lower())
            else:
                seq[128] = sequence.encode_to_onehot(row.refAllele.lower())
        else:
            # sequence too close to begining
            seq = sequence.encode_to_onehot(genome[row.chr][0:256])
            if alt:
                seq[row.position] = sequence.encode_to_onehot(row.altAllele.lower())
            else:
                seq[row.position] = sequence.encode_to_onehot(row.refAllele.lower())
        if seq.shape != (256, 4):
            # seq too close to end?
            print('Sequence at ' +str(row.chr) + ' ' + str(row.position) + ' is too short!')
            offset = 0
            while seq.shape != (256, 4) and offset < 128:
                offset += 1
                seq = sequence.encode_to_onehot(genome[row.chr][row.position-128-offset:row.position+128-offset])
            if alt:
                seq[128-offset] = sequence.encode_to_onehot(row.altAllele.lower())
            else:
                seq[128-offset] = sequence.encode_to_onehot(row.refAllele.lower())
        if (row.refAllele).lower() != (genome[row.chr][row.position]).lower():
             raise IndexError('Reference allele does not match reference genome')
        if seq.shape == (256, 4):
            yield seq
        else:
            print('Sequence at ' +str(row.chr) + ' ' + str(row.position) + ' couldn\'t be fixed')
