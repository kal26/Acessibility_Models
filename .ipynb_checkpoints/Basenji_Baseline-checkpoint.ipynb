# %%
import os
import sys
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
sys.path.append('/home/kal/TF_models/bin/')
sys.path.append('/home/thouis/basenji_embeddings')


import tf_memory_limit
from zinb import ZINB

import seaborn as sns

import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Dense, Dropout
from keras.optimizers import RMSprop, SGD
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras import backend as K
import tensorflow as tf
import numpy as np

d = np.load("embedding_files/chr1_40894464_41025536.npz")
embeds = d['embeddings']
num_inputs = embeds.shape[-1]

counts = {}
count_data = np.load('/mnt/DATA2/thouis/GM12878/chr1_to_chr10_counts.npz')
for k in count_data.keys():
    counts[k] = count_data[k]
num_outputs = count_data['chr1'].shape[1]

(num_inputs, num_outputs), count_data_chr1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-18501bf77f0a> in <module>()
#      19 import tensorflow as tf
#      20
# ---> 21 d = np.load("embedding_files/chr1_40894464_41025536.npz")
#      22 embeds = d['embeddings']
#      23 num_inputs = embeds.shape[-1]
#
# NameError: name 'np' is not defined

# %%
# from predict_basenji_chr1.py
seq_input_size = 131072
seq_half = seq_input_size // 2

import glob
import random
embed_files = glob.glob('embedding_files/chr*.npz')

def datagen(infiles, counts):
    assert len(infiles) > 1
    infiles = [f for f in infiles]  # copy for shuffling
    halfstep = False
    while True:
        random.shuffle(infiles)
        for f in infiles:
            embed = np.load(f)['embeddings']
            chr, start, end = f.split('/')[-1].split('_')
            start = int(start)
            end = int(end[:-4])  # trim .npz
            if not halfstep:
                embed = embed[0, ...]
            else:
                embed = embed[1, ...]
                start += seq_half
                end += seq_half
            halfstep = random.choice([True, False])
            start128 = start // 128
            end128 = end // 128
            subcounts = counts[chr][start128:end128, :]
            smoothed = 0.5 * subcounts
            smoothed[1:, :] += 0.25 * subcounts[:-1, :]
            smoothed[:-1, :] += 0.25 * subcounts[1:, :]
            yield embed, smoothed

def chrnum(f):
    chr = f.split('/')[-1].split('_')[0]
    return int(chr[3:])

def traingen():
    chrfiles = [f for f in embed_files if chrnum(f) < 8]
    for a, b in datagen(chrfiles, counts):
        yield a, b

def valgen():
    chrfiles = [f for f in embed_files if chrnum(f) >= 8]
    for a, b in datagen(chrfiles, counts):
        yield a, b

a, b = next(traingen())
a.shape, b.shape
# Out:
# ((1024, 717), (1024, 344))

# %%
# MODEL
inputs = Input(shape=(num_inputs,))
dropped = Dropout(0.5)(inputs)
expand = Dense(num_outputs * 3, activation = None)(dropped)
predictions = Dense(num_outputs, activation=tf.exp)(expand)
model = Model(inputs=inputs, outputs=predictions)

pi_layer = Dense(num_outputs, activation='sigmoid')
pi = pi_layer(expand)
zinb = ZINB(pi, theta_init=tf.zeros([1, num_outputs]))

model.layers[-1].trainable_weights.extend([zinb.theta_variable,
                                           *pi_layer.trainable_weights])

# %%
from keras.optimizers import RMSprop, SGD, Adam


opt = RMSprop(lr=1e-5)
opt = SGD(lr=1e-3, momentum=0.9)
model.compile(optimizer=opt,
              loss=zinb.loss)  # zinb loss function

early_stop = EarlyStopping(monitor='val_loss', patience=100)
filepath="weights-{epoch:02d}-{val_loss:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
losses = model.fit_generator(traingen(), steps_per_epoch=1000, epochs=2000,
                   callbacks=[early_stop, checkpoint],
                   validation_data=valgen(), validation_steps=400, verbose=2)


val_hist = losses.history['val_loss']
train_hist = losses.history['loss']
# Out:
# Epoch 1/2000
# Epoch 00000: val_loss improved from inf to 1.93979, saving model to weights-00-1.940.hdf5
# 95s - loss: 2.4792 - val_loss: 1.9398
# Epoch 2/2000
# Epoch 00001: val_loss improved from 1.93979 to 1.84879, saving model to weights-01-1.849.hdf5
# 103s - loss: 2.0976 - val_loss: 1.8488
# Epoch 3/2000
# Epoch 00002: val_loss improved from 1.84879 to 1.82593, saving model to weights-02-1.826.hdf5
# 107s - loss: 1.9954 - val_loss: 1.8259
# Epoch 4/2000
# Epoch 00003: val_loss improved from 1.82593 to 1.77118, saving model to weights-03-1.771.hdf5
# 108s - loss: 1.9744 - val_loss: 1.7712
# Epoch 5/2000
# Epoch 00004: val_loss improved from 1.77118 to 1.76794, saving model to weights-04-1.768.hdf5
# 118s - loss: 1.9147 - val_loss: 1.7679
# Epoch 6/2000
# Epoch 00005: val_loss improved from 1.76794 to 1.73868, saving model to weights-05-1.739.hdf5
# 99s - loss: 1.9299 - val_loss: 1.7387
# Epoch 7/2000
# Epoch 00006: val_loss did not improve
# 98s - loss: 1.9141 - val_loss: 1.7430
# Epoch 8/2000
# Epoch 00007: val_loss improved from 1.73868 to 1.73845, saving model to weights-07-1.738.hdf5
# 98s - loss: 1.8809 - val_loss: 1.7384
# Epoch 9/2000
# Epoch 00008: val_loss improved from 1.73845 to 1.68917, saving model to weights-08-1.689.hdf5
# 96s - loss: 1.8764 - val_loss: 1.6892
# Epoch 10/2000
# Epoch 00009: val_loss did not improve
# 99s - loss: 1.8916 - val_loss: 1.7342
# Epoch 11/2000
# Epoch 00010: val_loss did not improve
# 99s - loss: 1.8867 - val_loss: 1.6908
# Epoch 12/2000
# Epoch 00011: val_loss did not improve
# 94s - loss: 1.8851 - val_loss: 1.7099
# Epoch 13/2000
# Epoch 00012: val_loss did not improve
# 101s - loss: 1.8722 - val_loss: 1.7200
# Epoch 14/2000
# Epoch 00015: val_loss improved from 1.68917 to 1.67258, saving model to weights-15-1.673.hdf5
# 101s - loss: 1.8451 - val_loss: 1.6726
# Epoch 17/2000
# Epoch 00016: val_loss improved from 1.67258 to 1.62422, saving model to weights-16-1.624.hdf5
# 99s - loss: 1.8413 - val_loss: 1.6242
# Epoch 18/2000
# Epoch 00017: val_loss did not improve
# 106s - loss: 1.8498 - val_loss: 1.6788
# Epoch 19/2000
# Epoch 00018: val_loss did not improve
# 99s - loss: 1.8247 - val_loss: 1.6764
# Epoch 20/2000
# Epoch 00019: val_loss did not improve
# 100s - loss: 1.8672 - val_loss: 1.6829
# Epoch 21/2000
# Epoch 00020: val_loss did not improve
# 100s - loss: 1.8661 - val_loss: 1.6635
# Epoch 22/2000
# Epoch 00021: val_loss did not improve
# 96s - loss: 1.8660 - val_loss: 1.6640
# Epoch 23/2000
# Epoch 00022: val_loss did not improve
# 98s - loss: 1.8264 - val_loss: 1.6424
# Epoch 24/2000
# Epoch 00023: val_loss did not improve
# 100s - loss: 1.8260 - val_loss: 1.6941
# Epoch 25/2000
# Epoch 00024: val_loss did not improve
# 99s - loss: 1.8356 - val_loss: 1.6772
# Epoch 26/2000
# Epoch 00025: val_loss did not improve
# 100s - loss: 1.8523 - val_loss: 1.6663
# Epoch 27/2000
# Epoch 00026: val_loss did not improve
# 111s - loss: 1.8370 - val_loss: 1.6903
# Epoch 28/2000
# Epoch 00027: val_loss improved from 1.62422 to 1.62141, saving model to weights-27-1.621.hdf5
# 101s - loss: 1.8337 - val_loss: 1.6214
# Epoch 29/2000
# Epoch 00028: val_loss did not improve
# 101s - loss: 1.8196 - val_loss: 1.7085
# Epoch 30/2000
# Epoch 00029: val_loss did not improve
# 99s - loss: 1.8527 - val_loss: 1.6447
# Epoch 31/2000
# Epoch 00030: val_loss did not improve
# 102s - loss: 1.8333 - val_loss: 1.6308
# Epoch 32/2000
# Epoch 00031: val_loss did not improve
# 97s - loss: 1.8517 - val_loss: 1.6758
# Epoch 33/2000
# Epoch 00032: val_loss did not improve
# 90s - loss: 1.8323 - val_loss: 1.6661
# Epoch 34/2000
# Epoch 00033: val_loss did not improve
# 98s - loss: 1.8315 - val_loss: 1.6697
# Epoch 35/2000
# Epoch 00034: val_loss did not improve
# 100s - loss: 1.8294 - val_loss: 1.6536
# Epoch 36/2000
# Epoch 00035: val_loss did not improve
# 99s - loss: 1.8238 - val_loss: 1.6677
# Epoch 37/2000
# Epoch 00036: val_loss did not improve
# 100s - loss: 1.8483 - val_loss: 1.6395
# Epoch 38/2000
# Epoch 00037: val_loss did not improve
# 100s - loss: 1.8331 - val_loss: 1.6830
# Epoch 39/2000
# Epoch 00038: val_loss did not improve
# 99s - loss: 1.8123 - val_loss: 1.6272
# Epoch 40/2000
# Epoch 00039: val_loss improved from 1.62141 to 1.61808, saving model to weights-39-1.618.hdf5
# 100s - loss: 1.8117 - val_loss: 1.6181
# Epoch 41/2000
# Epoch 00040: val_loss did not improve
# 98s - loss: 1.8334 - val_loss: 1.6245
# Epoch 42/2000
# Epoch 00041: val_loss did not improve
# 98s - loss: 1.8124 - val_loss: 1.6573
# Epoch 43/2000
# Epoch 00042: val_loss did not improve
# 95s - loss: 1.8359 - val_loss: 1.6872
# Epoch 44/2000
# Epoch 00043: val_loss did not improve
# 96s - loss: 1.8097 - val_loss: 1.6240
# Epoch 45/2000
# Epoch 00044: val_loss did not improve
# 99s - loss: 1.8140 - val_loss: 1.6745
# Epoch 46/2000
# Epoch 00045: val_loss did not improve
# 99s - loss: 1.8356 - val_loss: 1.6503
# Epoch 47/2000
# Epoch 00046: val_loss did not improve
# 99s - loss: 1.8278 - val_loss: 1.6533
# Epoch 48/2000
# Epoch 00047: val_loss did not improve
# 98s - loss: 1.8253 - val_loss: 1.6248
# Epoch 49/2000
# Epoch 00048: val_loss did not improve
# 95s - loss: 1.8205 - val_loss: 1.6857
# Epoch 50/2000
# Epoch 00049: val_loss did not improve
# 100s - loss: 1.8196 - val_loss: 1.6369
# Epoch 51/2000
# Epoch 00050: val_loss did not improve
# 97s - loss: 1.8202 - val_loss: 1.6561
# Epoch 52/2000
# Epoch 00051: val_loss did not improve
# 99s - loss: 1.8128 - val_loss: 1.6359
# Epoch 53/2000
# Epoch 00052: val_loss did not improve
# 99s - loss: 1.8084 - val_loss: 1.7104
# Epoch 54/2000
# Epoch 00053: val_loss did not improve
# 93s - loss: 1.8168 - val_loss: 1.6845
# Epoch 55/2000
# Epoch 00054: val_loss did not improve
# 97s - loss: 1.7952 - val_loss: 1.6227
# Epoch 56/2000
# Epoch 00055: val_loss improved from 1.61808 to 1.61770, saving model to weights-55-1.618.hdf5
# 99s - loss: 1.8320 - val_loss: 1.6177
# Epoch 57/2000
# Epoch 00056: val_loss did not improve
# 94s - loss: 1.8241 - val_loss: 1.6478
# Epoch 58/2000
# Epoch 00057: val_loss did not improve
# 97s - loss: 1.7985 - val_loss: 1.6454
# Epoch 59/2000
# Epoch 00058: val_loss did not improve
# 99s - loss: 1.8040 - val_loss: 1.6946
# Epoch 60/2000
# Epoch 00059: val_loss did not improve
# 99s - loss: 1.8141 - val_loss: 1.6515
# Epoch 61/2000
# Epoch 00060: val_loss did not improve
# 99s - loss: 1.8105 - val_loss: 1.6341
# Epoch 62/2000
# Epoch 00061: val_loss did not improve
# 99s - loss: 1.8176 - val_loss: 1.6706
# Epoch 63/2000
# Epoch 00062: val_loss did not improve
# 97s - loss: 1.8212 - val_loss: 1.6402
# Epoch 64/2000
# Epoch 00063: val_loss did not improve
# 96s - loss: 1.8275 - val_loss: 1.6867
# Epoch 65/2000
# Epoch 00064: val_loss improved from 1.61770 to 1.60936, saving model to weights-64-1.609.hdf5
# 92s - loss: 1.8174 - val_loss: 1.6094
# Epoch 66/2000
# Epoch 00065: val_loss did not improve
# 98s - loss: 1.8140 - val_loss: 1.6495
# Epoch 67/2000
# Epoch 00066: val_loss did not improve
# 98s - loss: 1.8208 - val_loss: 1.6800
# Epoch 68/2000
# Epoch 00067: val_loss did not improve
# 99s - loss: 1.8163 - val_loss: 1.6716
# Epoch 69/2000
# Epoch 00068: val_loss improved from 1.60936 to 1.59994, saving model to weights-68-1.600.hdf5
# 98s - loss: 1.8054 - val_loss: 1.5999
# Epoch 70/2000
# Epoch 00069: val_loss did not improve
# 99s - loss: 1.7972 - val_loss: 1.6596
# Epoch 71/2000
# Epoch 00070: val_loss did not improve
# 100s - loss: 1.7966 - val_loss: 1.6363
# Epoch 72/2000
# Epoch 00071: val_loss did not improve
# 99s - loss: 1.7964 - val_loss: 1.6314
# Epoch 73/2000
# Epoch 00072: val_loss did not improve
# 96s - loss: 1.8146 - val_loss: 1.6589
# Epoch 74/2000
# Epoch 00073: val_loss did not improve
# 97s - loss: 1.8078 - val_loss: 1.6407
# Epoch 75/2000
# Epoch 00074: val_loss did not improve
# 93s - loss: 1.8039 - val_loss: 1.6941
# Epoch 76/2000
# Epoch 00075: val_loss improved from 1.59994 to 1.57313, saving model to weights-75-1.573.hdf5
# 97s - loss: 1.7949 - val_loss: 1.5731
# Epoch 77/2000
# Epoch 00076: val_loss did not improve
# 99s - loss: 1.8092 - val_loss: 1.6039
# Epoch 78/2000
# Epoch 00077: val_loss did not improve
# 99s - loss: 1.8224 - val_loss: 1.6172
# Epoch 79/2000
# Epoch 00078: val_loss did not improve
# 98s - loss: 1.8063 - val_loss: 1.6929
# Epoch 80/2000
# Epoch 00079: val_loss did not improve
# 100s - loss: 1.8182 - val_loss: 1.6662
# Epoch 81/2000
# Epoch 00080: val_loss did not improve
# 96s - loss: 1.8104 - val_loss: 1.6740
# Epoch 82/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-166-6e8804c8ba60> in <module>()
#      12 losses = model.fit_generator(traingen(), steps_per_epoch=1000, epochs=2000,
#      13                    callbacks=[early_stop, checkpoint],
# ---> 14                    validation_data=valgen(), validation_steps=400, verbose=2)
#      15
#      16
#
# /home/thouis/VENV/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                         signature += str_val
#      86                     if i < len(kwargs) - 1:
# ---> 87                         signature += ', '
#      88                 signature += ')`'
#      89                 warnings.warn('Update your `' + object_name +
#
# /home/thouis/VENV/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#
# /home/thouis/VENV/lib/python3.5/site-packages/keras/utils/data_utils.py in get(self)
#     642         self._manager = None
#     643         self.queue = None
# --> 644         self.seed = seed
#     645
#     646     def _data_generator_task(self):
#
# KeyboardInterrupt:

# %%
train_hist[:10]
# Out:
# [1.7684967417791486,
#  1.7797533558309078,
#  1.7888142464086414,
#  1.7954626668542624,
#  1.7839959416016937,
#  1.8031786477789282,
#  1.7884251243323088,
#  1.7775699646398424,
#  1.8158681159615517,
#  1.7927107188105582]

# %%
model.load_weights('weights-75-1.573.hdf5')

# %%
a, b = next(valgen())
p = model.predict_on_batch(a)

# %%
n = p.max(axis=0, keepdims=True)
len(plot(log(p / n)))
# Out:
# 344

# %%
plot(log(b / n));
# Out:
# /home/thouis/VENV/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
from scipy.stats import pearsonr, spearmanr

sub = 16
ps = p.cumsum(axis=0)
ps = ps[sub::sub] - ps[:-sub:sub]
bs = b.cumsum(axis=0)
bs = bs[sub::sub] - bs[:-sub:sub]

Rs = [pearsonr(ps[:, idx], bs[:, idx])[0] for idx in range(344)]
hist(Rs, 'auto');

# %%
(array(Rs) >0.8).nonzero()
# Out:
# (array([128, 132, 316]),)

# %%
scatter(log(ps[:, 33]), log(bs[:, 33]))
# xlim(0, 20)
#ylim(0, 20)

# %%
figure(figsize=(15,5))
mp = log((ps+ 10)).mean(axis=1, keepdims=True)+ log((ps+ 10)).mean(axis=0, keepdims=True)
len(plot((log(ps + 10) - mp)[:, 128]))
# Out:
# 1

# %%
figure(figsize=(15,5))
m = log((bs+ 10)).mean(axis=1, keepdims=True)+ log((bs+ 10)).mean(axis=0, keepdims=True)
len(plot((log(bs + 10) - m)[:, 128]))
# Out:
# 1

# %%
scatter((log(bs + 1) - m)[:, 318], (log(ps + 1) - mp)[:, 318])

# %%
from scipy.stats import pearsonr, spearmanr

Rs = [pearsonr((ps - mp)[:, idx], (bs - m)[:, idx])[0] for idx in range(344)]
hist(Rs, 'auto');

# %%
(array(Rs) > .6).nonzero()
# Out:
# (array([  5,   7,   8,   9,  11,  14,  15,  97, 160, 161, 171, 230, 273,
#         274, 317, 318, 326]),)

# %%
bamlist = [l.strip() for l in open("/mnt/DATA2/thouis/GM12878/bamlist.txt")]
d_to_g = {l.split('/')[0]: l.split('"')[1] for l in open("/mnt/DATA2/thouis/GM12878/file_to_gene.txt")}

# %%
g = [d_to_g[s.split('/')[1]] for s in bamlist]

# %%
# Out:
# ['CEBPZ',
#  'CEBPZ',
#  'POLR2A',
#  'POLR2A',
#  'ZNF622',
#  'ZNF622',
#  'TBL1XR1',
#  'TBL1XR1',
#  'E2F8',
#  'E2F8',
#  'TRIM22',
#  'TRIM22',
#  'USF1',
#  'USF1',
#  'SIX5',
#  'SIX5',
#  'IKZF1',
#  'IKZF1',
#  'UBTF',
#  'UBTF',
#  'EED',
#  'EED',
#  'ASH2L',
#  'ASH2L',
#  'SKIL',
#  'SKIL',
#  'NBN',
#  'NBN',
#  'RELA',
#  'RELA',
#  'RELA',
#  'RELA',
#  'IRF3',
#  'IRF3',
#  'E4F1',
#  'E4F1',
#  'MXI1',
#  'MXI1',
#  'POLR2A',
#  'POLR2A',
#  'TBP',
#  'TBP',
#  'ELK1',
#  'ELK1',
#  'RUNX3',
#  'RUNX3',
#  'NR2C2',
#  'NR2C2',
#  'SMAD1',
#  'SMAD1',
#  'BCLAF1',
#  'BCLAF1',
#  'TRIM22',
#  'TRIM22',
#  'PBX3',
#  'PBX3',
#  'RAD51',
#  'RAD51',
#  'RB1',
#  'RB1',
#  'RXRA',
#  'RXRA',
#  'MYC',
#  'MYC',
#  'IRF5',
#  'IRF5',
#  'CTCF',
#  'CTCF',
#  'MAX',
#  'MAX',
#  'PAX8',
#  'PAX8',
#  'IKZF1',
#  'IKZF1',
#  'STAT3',
#  'STAT3',
#  'MLLT1',
#  'MLLT1',
#  'ZNF207',
#  'ZNF207',
#  'SRF',
#  'SRF',
#  'REST',
#  'REST',
#  'HSF1',
#  'HSF1',
#  'RELB',
#  'RELB',
#  'BMI1',
#  'BMI1',
#  'NRF1',
#  'NRF1',
#  'SMAD5',
#  'SMAD5',
#  'CTCF',
#  'CTCF',
#  'NFE2',
#  'NFE2',
#  'ZNF384',
#  'ZNF384',
#  'CEBPB',
#  'CEBPB',
#  'BATF',
#  'BATF',
#  'PAX5',
#  'PAX5',
#  'NFXL1',
#  'NFXL1',
#  'BRCA1',
#  'BRCA1',
#  'IKZF2',
#  'IKZF2',
#  'MYB',
#  'MYB',
#  'E2F4',
#  'E2F4',
#  'ZNF143',
#  'ZNF143',
#  'HDGF',
#  'HDGF',
#  'SPI1',
#  'SPI1',
#  'NFIC',
#  'NFIC',
#  'CHD1',
#  'CHD1',
#  'ZEB1',
#  'ZEB1',
#  'SMC3',
#  'SMC3',
#  'CTCF',
#  'CTCF',
#  'CTCF',
#  'CUX1',
#  'CUX1',
#  'BHLHE40',
#  'BHLHE40',
#  'ZBTB40',
#  'ZBTB40',
#  'NFYA',
#  'NFYA',
#  'EP300',
#  'EP300',
#  'BCLAF1',
#  'BCLAF1',
#  'SRF',
#  'SRF',
#  'MEF2C',
#  'MEF2C',
#  'ATF2',
#  'ATF2',
#  'POLR3G',
#  'POLR3G',
#  'ZZZ3',
#  'ZZZ3',
#  'USF2',
#  'USF2',
#  'SP1',
#  'SP1',
#  'DPF2',
#  'DPF2',
#  'ZBED1',
#  'ZBED1',
#  'HDAC2',
#  'HDAC2',
#  'EP300',
#  'EP300',
#  'YBX1',
#  'YBX1',
#  'RAD21',
#  'RAD21',
#  'ZNF24',
#  'ZNF24',
#  'KDM1A',
#  'KDM1A',
#  'EGR1',
#  'SMARCA5',
#  'SMARCA5',
#  'RBBP5',
#  'RBBP5',
#  'CBFB',
#  'CBFB',
#  'SRF',
#  'SRF',
#  'IKZF1',
#  'IKZF1',
#  'TBX21',
#  'TBX21',
#  'ETV6',
#  'ETV6',
#  'POLR2A',
#  'POLR2A',
#  'POLR2A',
#  'POLR2A',
#  'YY1',
#  'YY1',
#  'TARDBP',
#  'TARDBP',
#  'ZFP36',
#  'ZFP36',
#  'IRF3',
#  'IRF3',
#  'JUND',
#  'JUND',
#  'ZBTB33',
#  'ZBTB33',
#  'HCFC1',
#  'HCFC1',
#  'ZNF592',
#  'ZNF592',
#  'BCL3',
#  'BCL3',
#  'RCOR1',
#  'RCOR1',
#  'CREM',
#  'CREM',
#  'ARNT',
#  'ARNT',
#  'SIN3A',
#  'SIN3A',
#  'POLR2A',
#  'POLR2A',
#  'POLR2A',
#  'POLR2A',
#  'MEF2A',
#  'MEF2A',
#  'MAZ',
#  'MAZ',
#  'NFYB',
#  'NFYB',
#  'NR2F1',
#  'NR2F1',
#  'TARDBP',
#  'TARDBP',
#  'HDAC6',
#  'MTA3',
#  'MTA3',
#  'ARID3A',
#  'ARID3A',
#  'ETS1',
#  'ETS1',
#  'NFATC1',
#  'NFATC1',
#  'JUNB',
#  'JUNB',
#  'CBX5',
#  'CBX5',
#  'NR2C1',
#  'NR2C1',
#  'ATF2',
#  'ATF2',
#  'BACH1',
#  'BACH1',
#  'JUND',
#  'JUND',
#  'ZNF143',
#  'ZNF143',
#  'CHD2',
#  'CHD2',
#  'ESRRA',
#  'ESRRA',
#  'RFX5',
#  'RFX5',
#  'NFATC3',
#  'NFATC3',
#  'MTA2',
#  'MTA2',
#  'EBF1',
#  'EBF1',
#  'FOXK2',
#  'FOXK2',
#  'TCF12',
#  'TCF12',
#  'GATAD2B',
#  'GATAD2B',
#  'ZNF687',
#  'ZNF687',
#  'CREB1',
#  'CREB1',
#  'ETV6',
#  'ETV6',
#  'ATF7',
#  'ATF7',
#  'ZBTB33',
#  'ZBTB33',
#  'FOS',
#  'FOS',
#  'FOS',
#  'TAF1',
#  'TAF1',
#  'BHLHE40',
#  'BHLHE40',
#  'YY1',
#  'STAT1',
#  'STAT1',
#  'ZNF217',
#  'ZNF217',
#  'BCL11A',
#  'BCL11A',
#  'EP300',
#  'EP300',
#  'CBX3',
#  'CBX3',
#  'STAT5A',
#  'STAT5A',
#  'MEF2B',
#  'MEF2B',
#  'RAD21',
#  'RAD21',
#  'REST',
#  'REST',
#  'GABPA',
#  'GABPA',
#  'SUZ12',
#  'TCF12',
#  'TCF12',
#  'CTCF',
#  'CTCF',
#  'MAFK',
#  'MAFK',
#  'ZSCAN29',
#  'ZSCAN29',
#  'KLF5',
#  'KLF5',
#  'IKZF2',
#  'IKZF2',
#  'TCF7',
#  'TCF7',
#  'PAX5',
#  'PAX5',
#  'ELF1',
#  'ELF1',
#  'CHD4',
#  'CHD4',
#  'IRF4',
#  'IRF4',
#  'PKNOX1',
#  'PKNOX1',
#  'EBF1',
#  'EBF1',
#  'WRNIP1',
#  'WRNIP1',
#  'EZH2',
#  'EZH2']

# %%
genelist = list(set(g))
g_to_i = [genelist.index(gn) for gn in g]

# %%
def merge(vals):
    out = np.zeros((vals.shape[0], len(genelist)))
    for i, gi in enumerate(g_to_i):
        out[:, gi] += vals[:, i]
    return out

# %%
figure(figsize=(15,5))
psm = merge(ps)
mp = log((psm+ 10)).mean(axis=1, keepdims=True)+ log((psm+ 10)).mean(axis=0, keepdims=True)
len(plot((log(psm + 10) - mp)[:, 134]))
# Out:
# 1

# %%
figure(figsize=(15,5))
bsm = merge(bs)
m = log((bsm+ 10)).mean(axis=1, keepdims=True)+ log((bsm+ 10)).mean(axis=0, keepdims=True)
len(plot((log(bsm + 10) - m)[:, 134]))
# Out:
# 1

# %%
from scipy.stats import pearsonr, spearmanr

Rs = [pearsonr((psm - mp)[:, idx], (bsm - m)[:, idx])[0] for idx in range(141)]
hist(Rs, 'auto');

# %%
scatter((log(bsm + 1) - m)[:, 13], (log(psm + 1) - mp)[:, 13])

# %%
for i, n in enumerate(genelist):
    figure(figsize=(8, 8))
    scatter((log(bsm + 1) - m)[:, i], (log(psm + 1) - mp)[:, i])
    title(n)
# Out:
# /home/thouis/VENV/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
print("\t".join(genelist))
# Out:
# MAFK	RAD21	MTA2	SMC3	USF2	CUX1	BHLHE40	RBBP5	ATF7	NFIC	MAZ	CREM	ZNF143	STAT3	ZBTB33	TRIM22	SUZ12	CBFB	STAT5A	ELF1	DPF2	SIX5	RB1	CTCF	BRCA1	RAD51	IRF4	EZH2	RCOR1	NFATC3	GATAD2B	MEF2B	TBP	RELB	E4F1	CEBPZ	NFE2	ZNF592	ZZZ3	ARNT	RELA	MAX	STAT1	SKIL	USF1	JUND	PAX8	CHD1	BCL3	FOXK2	SMARCA5	SMAD5	BATF	POLR3G	MLLT1	ETS1	E2F4	ASH2L	GABPA	ELK1	NRF1	NFYA	MTA3	EBF1	KLF5	IRF3	NR2C1	PBX3	RXRA	MEF2A	ESRRA	SPI1	HSF1	ETV6	WRNIP1	UBTF	ZNF217	HDAC6	TBL1XR1	NFXL1	ZNF687	CHD4	CBX3	NFATC1	ARID3A	CEBPB	ZEB1	SIN3A	ZNF384	CREB1	ZBED1	POLR2A	IKZF2	YBX1	EED	CBX5	ATF2	TCF12	NBN	EP300	SMAD1	SRF	ZNF622	RUNX3	IRF5	MYC	MEF2C	SP1	PAX5	TBX21	CHD2	E2F8	ZBTB40	IKZF1	HCFC1	HDGF	TARDBP	YY1	KDM1A	BCL11A	NR2F1	BCLAF1	NR2C2	MXI1	ZSCAN29	ZNF24	BACH1	MYB	EGR1	FOS	RFX5	ZNF207	HDAC2	TAF1	REST	BMI1	NFYB	JUNB	TCF7	ZFP36	PKNOX1
