# %% [raw]
# Train a convolutional model to predict log fold change f K27act from sequence and atac

# %%
import os
import sys
sys.path.append('/home/kal/TF_models/bin/')
sys.path.append('/home/kal/K27act_models/convolution_model/')
sys.path.append('/home/kal/K27act_models/cg_model/')
sys.path.append('/home/thouis/basenji_embeddings')
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import tf_memory_limit
from zinb import ZINB
import seaborn as sns
import h5py
import matplotlib.pyplot as plt
from keras.utils import plot_model

import pandas as pd
import numpy as np
import itertools
import sequence
import helper
import viz_sequence
import ucscgenome
from tqdm import tqdm
import time
import datagen

from keras.models import Model
from keras.layers import Input, Dense, SpatialDropout1D, Conv1D, Lambda
from keras.optimizers import RMSprop, SGD
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras import backend as K
import tensorflow as tf

# %%
#load in the DNA
genome = ucscgenome.Genome('/home/kal/.ucscgenome/hg19.2bit')

# %%
# load in ATAC data
atac_path = '/home/kal/K27act_models/GM_data/ATAC/atac_average.hdf5'
atac = h5py.File(atac_path, 'r')

# %%
# load in peaks data
peaks_path = '/home/kal/K27act_models/GM_data/merged_annotated.bed'
peaks = pd.read_table(peaks_path, header=None)
peaks.columns='chr narrowstart narrowend name score atac k27act'.split()

peaks['start'] = (peaks['narrowend'] + peaks['narrowstart'])//2 - 512
peaks['end'] = (peaks['narrowend'] + peaks['narrowstart'])//2 + 512

# %%
# preproces the data
for idx, row in tqdm(peaks.iterrows(), total=len(peaks)):
    peaks.set_value(idx, 'nucs', genome[row.chr][row.start:row.end])
    #mini.set_value(idx, 'coverage', atac[row.chr][row.start:row.end])
    
columns='chr start end name score atac k27act nucs'.split()
peaks.to_csv('/home/kal/K27act_models/GM_data/k27act_training_regions.bed', columns=columns, header=None, index=False, sep='\t')

# %%
# load in preprocessed data
peaks_path = '/home/kal/K27act_models/GM_data/k27act_training_regions.bed'
peaks = pd.read_table(peaks_path, header=None)
peaks.columns='chr start end name score atac k27act nucs'.split()

# %%
# facts about the data
num_training_samples = len(peaks[(peaks.chr != 'chr8')])
print('{} training samples'.format(num_training_samples))

num_testing_samples = len(peaks[(peaks.chr == 'chr8') & (peaks.index%2 == 0)])
print('{} testing samples'.format(num_testing_samples))

num_validaiton_samples = len(peaks[(peaks.chr == 'chr8') & (peaks.index%2 == 1)])
print('{} validation samples'.format(num_validaiton_samples))
# Out:
# 140163 training samples
# 3011 testing samples
# 3011 validation samples

# %%
# directory stuff
out_dir = '/home/kal/K27act_models/convolution_model/'
timestr = time.strftime("%Y%m%d_%H%M%S")
out_path = os.path.join(out_dir, timestr + '_fold_pwm')
os.makedirs(out_path)
# make a file system
weights_path = os.path.join(out_path, 'intermediate_weights')
os.makedirs(weights_path)
history_path = os.path.join(out_path, 'history')
os.makedirs(history_path)

# %%
# MODEL
batch_size=32
seqs = Input(batch_shape=(batch_size, 1024, 5))

def add_RC(x):
    RC = K.concatenate([x[:, ::-1, :1], x[:, ::-1, 1:][::-1]], axis=2)
    return K.concatenate([x, RC], axis=0)
def add_RC_shape(s):
    return 2*s[0], s[1], s[2]

rc = Lambda(add_RC, name='add_rc', output_shape=add_RC_shape)(seqs)
conv = Conv1D(32, 32, name='conv_in')(rc)
dense = Dense(1)(conv)

def max_by_direction(x):
    forward_max = K.max(x[:x.shape[0]//2, :, :], axis=1)
    reverse_max = K.max(x[x.shape[0]//2:, ::-1, :], axis=1)
    return K.maximum(forward_max, reverse_max)
def max_by_direction_shape(s):
    return s[0]//2, 1

predictions = Lambda(max_by_direction, name='max_by_direciton', output_shape=max_by_direction_shape)(dense)
model = Model(inputs=seqs, outputs=predictions)

#plot model
plot_model(model, to_file=os.path.join(out_path, 'model.png'))

# %%
from keras.optimizers import RMSprop, SGD, Adam

opt = RMSprop(lr=1e-5)
model.compile(optimizer=opt, loss='mean_squared_error') 

early_stop = EarlyStopping(monitor='val_loss', patience=100)
filepath = os.path.join(weights_path, 'weights-{epoch:02d}-{val_loss:.3f}.hdf5')
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

losses = model.fit_generator(datagen.batch_gen(peaks, mode='train'), steps_per_epoch=num_training_samples//batch_size, 
                             epochs=20, callbacks=[early_stop, checkpoint], validation_data=datagen.batch_gen(peaks,mode='val'), 
                             validation_steps=num_validaiton_samples//batch_size, verbose=2)


val_hist = losses.history['val_loss']
train_hist = losses.history['loss']
# Out:
# Epoch 1/20
#  - 262s - loss: 2579.7660 - val_loss: 8.9458
#
# Epoch 00001: val_loss improved from inf to 8.94583, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-01-8.946.hdf5
# Epoch 2/20
#  - 262s - loss: 33.5619 - val_loss: 4.5872
#
# Epoch 00002: val_loss improved from 8.94583 to 4.58722, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-02-4.587.hdf5
# Epoch 3/20
#  - 262s - loss: 16.1787 - val_loss: 3.8393
#
# Epoch 00003: val_loss improved from 4.58722 to 3.83926, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-03-3.839.hdf5
# Epoch 4/20
#  - 263s - loss: 7.2196 - val_loss: 2.8313
#
# Epoch 00004: val_loss improved from 3.83926 to 2.83128, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-04-2.831.hdf5
# Epoch 5/20
#  - 262s - loss: 4.8710 - val_loss: 2.6464
#
# Epoch 00005: val_loss improved from 2.83128 to 2.64640, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-05-2.646.hdf5
# Epoch 6/20
#  - 262s - loss: 3.8504 - val_loss: 2.5591
#
# Epoch 00006: val_loss improved from 2.64640 to 2.55915, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-06-2.559.hdf5
# Epoch 7/20
#  - 259s - loss: 3.4685 - val_loss: 2.5991
#
# Epoch 00007: val_loss did not improve from 2.55915
# Epoch 8/20
#  - 259s - loss: 3.3839 - val_loss: 2.4881
#
# Epoch 00008: val_loss improved from 2.55915 to 2.48805, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-08-2.488.hdf5
# Epoch 9/20
#  - 259s - loss: 2.9767 - val_loss: 2.4715
#
# Epoch 00009: val_loss improved from 2.48805 to 2.47148, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-09-2.471.hdf5
# Epoch 10/20
#  - 259s - loss: 3.3166 - val_loss: 2.5221
#
# Epoch 00010: val_loss did not improve from 2.47148
# Epoch 11/20
#  - 260s - loss: 3.0321 - val_loss: 2.5556
#
# Epoch 00011: val_loss did not improve from 2.47148
# Epoch 12/20
#  - 260s - loss: 2.9734 - val_loss: 2.4547
#
# Epoch 00012: val_loss improved from 2.47148 to 2.45467, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-12-2.455.hdf5
# Epoch 13/20
#  - 262s - loss: 3.0608 - val_loss: 2.5089
#
# Epoch 00013: val_loss did not improve from 2.45467
# Epoch 14/20
#  - 268s - loss: 2.9753 - val_loss: 2.5246
#
# Epoch 00014: val_loss did not improve from 2.45467
# Epoch 15/20
#  - 275s - loss: 2.8895 - val_loss: 2.4539
#
# Epoch 00015: val_loss improved from 2.45467 to 2.45387, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-15-2.454.hdf5
# Epoch 16/20
#  - 272s - loss: 3.0198 - val_loss: 2.4870
#
# Epoch 00016: val_loss did not improve from 2.45387
# Epoch 17/20
#  - 265s - loss: 2.8311 - val_loss: 2.4910
#
# Epoch 00017: val_loss did not improve from 2.45387
# Epoch 18/20
#  - 262s - loss: 2.8896 - val_loss: 2.4547
#
# Epoch 00018: val_loss did not improve from 2.45387
# Epoch 19/20
#  - 269s - loss: 2.9328 - val_loss: 2.4514
#
# Epoch 00019: val_loss improved from 2.45387 to 2.45139, saving model to /home/kal/K27act_models/convolution_model/20180628_132455_fold_pwm/intermediate_weights/weights-19-2.451.hdf5
# Epoch 20/20
#  - 269s - loss: 2.8091 - val_loss: 2.4858
#
# Epoch 00020: val_loss did not improve from 2.45139

# %%
# final save
model_json = model.to_json()
with open(os.path.join(out_path, 'model.json'), 'w') as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(os.path.join(out_path, 'final_model.h5'))
print('Saved model')
# Out:
# Saved model

# %%
# look at loss
plt.plot(val_hist, label='validation')
plt.plot(train_hist, label='training')
plt.title('Loss for training model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim((0, 10))
plt.legend()
plt.show()

# %%
# look at kernels

# make a highlight map
from colour import Color

#what layers do we have to work with?
layer_dict = dict([(layer.name, layer) for layer in model.layers]) 
print(layer_dict.keys())

# plot weights from first layer neurons
#temp = .005
weight_array = layer_dict['conv_in'].get_weights()[0]
#for idx in range(weight_array.shape[2]):
for idx in range(1):
    
    #create highlight dict - with sane maxs and mins
    colors = list(Color("blue").range_to(Color("red"), 100))
    top = np.amax(weight_array[:, 0, :])
    bottom = np.amin(weight_array[:, 0, :])
    print('{}-{}'.format(top, bottom))
    color_weights = [int((x-bottom)/(top-bottom)*100) for x in weight[:,0]]
    print(color_weights)   
    highlight=dict()
    for i in range(len(weight)):
        w = color_weights[i]
        highlight[(colors[w].rgb[0],colors[w].rgb[1], colors[w].rgb[2], .3)] = [(i, i+1)]
    
    weight = weight_array[:,:,idx]
    kernel = sequence.Sequence(weight[:, 1:])
    plt.imshow(weight, cmap='plasma')
    plt.show()
    plt.figure(figsize=(20,2))
    plt.plot(weight[:,0])
    plt.show()
    viz_sequence.plot_icweights(helper.softmax(kernel.seq/temp*np.amax(kernel.seq)), highlight=highlight)
# Out:
# dict_keys(['input_3', 'add_rc', 'dense_2', 'conv_in', 'max_by_direciton'])
# 0.08832266926765442--0.08008445054292679
# [71, 37, 9, 41, 41, 33, 78, 29, 10, 70, 56, 13, 57, 11, 16, 32, 71, 71, 23, 47, 50, 13, 34, 47, 67, 18, 66, 96, 37, 88, 90, 22]
