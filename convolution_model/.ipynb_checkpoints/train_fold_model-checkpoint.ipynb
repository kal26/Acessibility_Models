# %% [raw]
# Train a more complex convolutional model to predict log fold change f K27act from sequence and atac

# %%
import os
import sys
sys.path.append('/home/kal/TF_models/bin/')
sys.path.append('/home/kal/K27act_models/convolution_model/')
sys.path.append('/home/kal/K27act_models/cg_model/')
sys.path.append('/home/thouis/basenji_embeddings')
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

import tf_memory_limit
from zinb import ZINB
import seaborn as sns
import h5py
import matplotlib.pyplot as plt
from keras.utils import plot_model

import pandas as pd
import numpy as np
import itertools
import sequence
import ucscgenome
from tqdm import tqdm
import time
import datagen
import sequence
import helper
import viz_sequence

from keras.models import Model
from keras.layers import Input, Dense, SpatialDropout1D, Conv1D, Lambda, Dropout
from keras.optimizers import RMSprop, SGD
from keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint
from keras import backend as K
import tensorflow as tf

import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
# Out:
# Using TensorFlow backend.
# /home/kal/TF_models/bin/sequence.py:275: RuntimeWarning: divide by zero encountered in log
#   self.seq = helper.softmax(np.log(dist))

# %%
#load in the DNA
genome = ucscgenome.Genome('/home/kal/.ucscgenome/hg19.2bit')

# %%
# load in ATAC data
atac_path = '/home/kal/K27act_models/GM_data/ATAC/atac_average.hdf5'
atac = h5py.File(atac_path, 'r')

# %%
# load in (semi) preprocessed data
peaks_path = '/home/kal/K27act_models/GM_data/k27act_training_regions.bed'
peaks = pd.read_table(peaks_path, header=None)
peaks.columns='chr start end name score atac k27act nucs'.split()

# %%
# facts about the data
num_training_samples = len(peaks[(peaks.chr != 'chr8')])
print('{} training samples'.format(num_training_samples))

num_testing_samples = len(peaks[(peaks.chr == 'chr8') & (peaks.index%2 == 0)])
print('{} testing samples'.format(num_testing_samples))

num_validaiton_samples = len(peaks[(peaks.chr == 'chr8') & (peaks.index%2 == 1)])
print('{} validation samples'.format(num_validaiton_samples))
# Out:
# 140163 training samples
# 3011 testing samples
# 3011 validation samples

# %%
# directory stuff
out_dir = '/home/kal/K27act_models/convolution_model/'
timestr = time.strftime("%Y%m%d_%H%M%S")
out_path = os.path.join(out_dir, timestr + '_conv_fold')
os.makedirs(out_path)
# make a file system
weights_path = os.path.join(out_path, 'intermediate_weights')
os.makedirs(weights_path)
history_path = os.path.join(out_path, 'history')
os.makedirs(history_path)

# %%
# MODEL
batch_size=32
seqs = Input(batch_shape=(batch_size, 1024, 5))

def add_RC(x):
    RC = K.concatenate([x[:, ::-1, :1], x[:, ::-1, 1:][::-1]], axis=2)
    return K.concatenate([x, RC], axis=0)
def add_RC_shape(s):
    return 2*s[0], s[1], s[2]

conv = Lambda(add_RC, name='add_rc', output_shape=add_RC_shape)(seqs)

for k, n in [[32, 3], [32, 32], [32, 3], [32, 3], [32,3]]:
    conv = Conv1D(k, n)(conv)
    conv = SpatialDropout1D(.05)(conv)

out = Dense(32)(conv) 
out = Dropout(.1)(out)
out = Dense(16)(out)
out = Dropout(.1)(out)
out = Dense(1)(out)

def max_by_direction(x):
    forward_max = K.max(x[:x.shape[0]//2, :, :], axis=1)
    reverse_max = K.max(x[x.shape[0]//2:, ::-1, :], axis=1)
    return K.maximum(forward_max, reverse_max)
def max_by_direction_shape(s):
    return s[0]//2, 1

predictions = Lambda(max_by_direction, name='max_by_direciton', output_shape=max_by_direction_shape)(out)
model = Model(inputs=seqs, outputs=predictions)

#plot model
plot_model(model, to_file=os.path.join(out_path, 'model.png'))

# %%
from keras.optimizers import RMSprop, SGD, Adam

opt_1 = Adam(beta_1=0.95, lr=0.0005, epsilon=.1)

    
    
model.compile(optimizer=opt_1, loss='mean_squared_error') 

early_stop = EarlyStopping(monitor='val_loss', patience=100)
filepath = os.path.join(weights_path, 'weights-1-{epoch:02d}-{val_loss:.3f}.hdf5')
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

losses_1 = model.fit_generator(datagen.batch_gen(peaks, mode='train'), steps_per_epoch=num_training_samples//batch_size, 
                             epochs=20, callbacks=[early_stop, checkpoint], validation_data=datagen.batch_gen(peaks,mode='val'), 
                             validation_steps=num_validaiton_samples//batch_size, verbose=2)

# drop learning rate
opt_2 = Adam(beta_1=0.95, lr=0.00005, epsilon=.001)
model.compile(optimizer=opt_2, loss='mean_squared_error') 

filepath = os.path.join(weights_path, 'weights-2-{epoch:02d}-{val_loss:.3f}.hdf5')
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

losses_2 = model.fit_generator(datagen.batch_gen(peaks, mode='train'), steps_per_epoch=num_training_samples//batch_size, 
                             epochs=20, callbacks=[early_stop, checkpoint], validation_data=datagen.batch_gen(peaks,mode='val'), 
                             validation_steps=num_validaiton_samples//batch_size, verbose=2)


# drop it again
opt_3 = Adam(beta_1=0.95, lr=0.000005, epsilon=.00001)
model.compile(optimizer=opt_3, loss='mean_squared_error') 

filepath = os.path.join(weights_path, 'weights-3-{epoch:02d}-{val_loss:.3f}.hdf5')
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

losses_3 = model.fit_generator(datagen.batch_gen(peaks, mode='train'), steps_per_epoch=num_training_samples//batch_size, 
                             epochs=20, callbacks=[early_stop, checkpoint], validation_data=datagen.batch_gen(peaks,mode='val'), 
                             validation_steps=num_validaiton_samples//batch_size, verbose=2)
# Out:
# Epoch 1/20
#  - 284s - loss: 226.6376 - val_loss: 64.4593
#
# Epoch 00001: val_loss improved from inf to 64.45934, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-01-64.459.hdf5
# Epoch 2/20
#  - 296s - loss: 84.9519 - val_loss: 19.2527
#
# Epoch 00002: val_loss improved from 64.45934 to 19.25273, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-02-19.253.hdf5
# Epoch 3/20
#  - 297s - loss: 19.0877 - val_loss: 8.1784
#
# Epoch 00003: val_loss improved from 19.25273 to 8.17843, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-03-8.178.hdf5
# Epoch 4/20
#  - 296s - loss: 4.9868 - val_loss: 3.2373
#
# Epoch 00004: val_loss improved from 8.17843 to 3.23727, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-04-3.237.hdf5
# Epoch 5/20
#  - 299s - loss: 3.1376 - val_loss: 3.1401
#
# Epoch 00005: val_loss improved from 3.23727 to 3.14007, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-05-3.140.hdf5
# Epoch 6/20
#  - 298s - loss: 2.8285 - val_loss: 2.6795
#
# Epoch 00006: val_loss improved from 3.14007 to 2.67948, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-06-2.679.hdf5
# Epoch 7/20
#  - 297s - loss: 2.7379 - val_loss: 2.6541
#
# Epoch 00007: val_loss improved from 2.67948 to 2.65413, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-07-2.654.hdf5
# Epoch 8/20
#  - 300s - loss: 2.7590 - val_loss: 2.5034
#
# Epoch 00008: val_loss improved from 2.65413 to 2.50337, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-08-2.503.hdf5
# Epoch 9/20
#  - 299s - loss: 2.6644 - val_loss: 2.6021
#
# Epoch 00009: val_loss did not improve from 2.50337
# Epoch 10/20
#  - 302s - loss: 2.7062 - val_loss: 2.4305
#
# Epoch 00010: val_loss improved from 2.50337 to 2.43050, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-10-2.430.hdf5
# Epoch 11/20
#  - 299s - loss: 2.7050 - val_loss: 2.5053
#
# Epoch 00011: val_loss did not improve from 2.43050
# Epoch 12/20
#  - 302s - loss: 2.6893 - val_loss: 2.4157
#
# Epoch 00012: val_loss improved from 2.43050 to 2.41575, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-1-12-2.416.hdf5
# Epoch 13/20
#  - 300s - loss: 2.6839 - val_loss: 2.4785
#
# Epoch 00013: val_loss did not improve from 2.41575
# Epoch 14/20
#  - 301s - loss: 2.6716 - val_loss: 2.5007
#
# Epoch 00014: val_loss did not improve from 2.41575
# Epoch 15/20
#  - 303s - loss: 2.8085 - val_loss: 2.4763
#
# Epoch 00015: val_loss did not improve from 2.41575
# Epoch 16/20
#  - 303s - loss: 2.6809 - val_loss: 2.5202
#
# Epoch 00016: val_loss did not improve from 2.41575
# Epoch 17/20
#  - 353s - loss: 2.6680 - val_loss: 2.4557
#
# Epoch 00017: val_loss did not improve from 2.41575
# Epoch 18/20
#  - 369s - loss: 2.6417 - val_loss: 2.5760
#
# Epoch 00018: val_loss did not improve from 2.41575
# Epoch 19/20
#  - 374s - loss: 2.6503 - val_loss: 2.4902
#
# Epoch 00019: val_loss did not improve from 2.41575
# Epoch 20/20
#  - 376s - loss: 2.6752 - val_loss: 2.4632
#
# Epoch 00020: val_loss did not improve from 2.41575
# Epoch 1/20
#  - 379s - loss: 2.6372 - val_loss: 2.4792
#
# Epoch 00001: val_loss improved from inf to 2.47924, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-2-01-2.479.hdf5
# Epoch 2/20
#  - 371s - loss: 2.6311 - val_loss: 2.4181
#
# Epoch 00002: val_loss improved from 2.47924 to 2.41813, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-2-02-2.418.hdf5
# Epoch 3/20
#  - 377s - loss: 2.6317 - val_loss: 2.4692
#
# Epoch 00003: val_loss did not improve from 2.41813
# Epoch 4/20
#  - 373s - loss: 2.6277 - val_loss: 2.4020
#
# Epoch 00004: val_loss improved from 2.41813 to 2.40203, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-2-04-2.402.hdf5
# Epoch 5/20
#  - 367s - loss: 2.6303 - val_loss: 2.4834
#
# Epoch 00005: val_loss did not improve from 2.40203
# Epoch 6/20
#  - 370s - loss: 2.6228 - val_loss: 2.4844
#
# Epoch 00006: val_loss did not improve from 2.40203
# Epoch 7/20
#  - 368s - loss: 2.6284 - val_loss: 2.4384
#
# Epoch 00007: val_loss did not improve from 2.40203
# Epoch 8/20
#  - 372s - loss: 2.6217 - val_loss: 2.5541
#
# Epoch 00008: val_loss did not improve from 2.40203
# Epoch 9/20
#  - 367s - loss: 2.6177 - val_loss: 2.4681
#
# Epoch 00009: val_loss did not improve from 2.40203
# Epoch 10/20
#  - 372s - loss: 2.6265 - val_loss: 2.4419
#
# Epoch 00010: val_loss did not improve from 2.40203
# Epoch 11/20
#  - 368s - loss: 2.6157 - val_loss: 2.4636
#
# Epoch 00011: val_loss did not improve from 2.40203
# Epoch 12/20
#  - 377s - loss: 2.6183 - val_loss: 2.4922
#
# Epoch 00012: val_loss did not improve from 2.40203
# Epoch 13/20
#  - 371s - loss: 2.6132 - val_loss: 2.4889
#
# Epoch 00013: val_loss did not improve from 2.40203
# Epoch 14/20
#  - 369s - loss: 2.6235 - val_loss: 2.4942
#
# Epoch 00014: val_loss did not improve from 2.40203
# Epoch 15/20
#  - 370s - loss: 2.6160 - val_loss: 2.4648
#
# Epoch 00015: val_loss did not improve from 2.40203
# Epoch 16/20
#  - 340s - loss: 2.6037 - val_loss: 2.3996
#
# Epoch 00016: val_loss improved from 2.40203 to 2.39955, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-2-16-2.400.hdf5
# Epoch 17/20
#  - 311s - loss: 2.6312 - val_loss: 2.4651
#
# Epoch 00017: val_loss did not improve from 2.39955
# Epoch 18/20
#  - 295s - loss: 2.6067 - val_loss: 2.4773
#
# Epoch 00018: val_loss did not improve from 2.39955
# Epoch 19/20
#  - 296s - loss: 2.6212 - val_loss: 2.5177
#
# Epoch 00019: val_loss did not improve from 2.39955
# Epoch 20/20
#  - 295s - loss: 2.6104 - val_loss: 2.4626
#
# Epoch 00020: val_loss did not improve from 2.39955
# Epoch 1/20
#  - 294s - loss: 2.6139 - val_loss: 2.4681
#
# Epoch 00001: val_loss improved from inf to 2.46814, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-3-01-2.468.hdf5
# Epoch 2/20
#  - 296s - loss: 2.6160 - val_loss: 2.5118
#
# Epoch 00002: val_loss did not improve from 2.46814
# Epoch 3/20
#  - 296s - loss: 2.6094 - val_loss: 2.4582
#
# Epoch 00003: val_loss improved from 2.46814 to 2.45816, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-3-03-2.458.hdf5
# Epoch 4/20
#  - 296s - loss: 2.6096 - val_loss: 2.4791
#
# Epoch 00004: val_loss did not improve from 2.45816
# Epoch 5/20
#  - 296s - loss: 2.6081 - val_loss: 2.5045
#
# Epoch 00005: val_loss did not improve from 2.45816
# Epoch 6/20
#  - 297s - loss: 2.6152 - val_loss: 2.4108
#
# Epoch 00006: val_loss improved from 2.45816 to 2.41080, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-3-06-2.411.hdf5
# Epoch 7/20
#  - 297s - loss: 2.6091 - val_loss: 2.4466
#
# Epoch 00007: val_loss did not improve from 2.41080
# Epoch 8/20
#  - 299s - loss: 2.6124 - val_loss: 2.4298
#
# Epoch 00008: val_loss did not improve from 2.41080
# Epoch 9/20
#  - 300s - loss: 2.6112 - val_loss: 2.4316
#
# Epoch 00009: val_loss did not improve from 2.41080
# Epoch 10/20
#  - 300s - loss: 2.6023 - val_loss: 2.3945
#
# Epoch 00010: val_loss improved from 2.41080 to 2.39450, saving model to /home/kal/K27act_models/convolution_model/20180702_153244_conv_fold/intermediate_weights/weights-3-10-2.395.hdf5
# Epoch 11/20
#  - 298s - loss: 2.6131 - val_loss: 2.4485
#
# Epoch 00011: val_loss did not improve from 2.39450
# Epoch 12/20
#  - 293s - loss: 2.6129 - val_loss: 2.4409
#
# Epoch 00012: val_loss did not improve from 2.39450
# Epoch 13/20
#  - 293s - loss: 2.6067 - val_loss: 2.4928
#
# Epoch 00013: val_loss did not improve from 2.39450
# Epoch 14/20
#  - 270s - loss: 2.6167 - val_loss: 2.4190
#
# Epoch 00014: val_loss did not improve from 2.39450
# Epoch 15/20
#  - 270s - loss: 2.6036 - val_loss: 2.4554
#
# Epoch 00015: val_loss did not improve from 2.39450
# Epoch 16/20
#  - 271s - loss: 2.6031 - val_loss: 2.4233
#
# Epoch 00016: val_loss did not improve from 2.39450
# Epoch 17/20
#  - 272s - loss: 2.6202 - val_loss: 2.5654
#
# Epoch 00017: val_loss did not improve from 2.39450
# Epoch 18/20
#  - 271s - loss: 2.6119 - val_loss: 2.4589
#
# Epoch 00018: val_loss did not improve from 2.39450
# Epoch 19/20
#  - 272s - loss: 2.6014 - val_loss: 2.4911
#
# Epoch 00019: val_loss did not improve from 2.39450
# Epoch 20/20
#  - 271s - loss: 2.6104 - val_loss: 2.5149
#
# Epoch 00020: val_loss did not improve from 2.39450

# %%
# final save
model.save(os.path.join(out_path, 'final_model.h5'))

# %%
# look at loss
val_hist = np.append(losses_1.history['val_loss'], losses_2.history['val_loss'])
val_hist = np.append(val_hist, losses_3.history['val_loss'])
train_hist = np.append(losses_1.history['loss'], losses_2.history['loss'])
train_hist = np.append(train_hist, losses_3.history['loss'])


plt.plot(val_hist, label='validation')
plt.plot(train_hist, label='training')
plt.title('Loss for training model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim((0, 30))
plt.legend()
plt.show()
